# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("/content/Task_9 Dataset.csv")
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# # **Dataset Description**
#
# The dataset is downloaded from UC Irvine Machine Learning Repository
#
# It contains the following features:
#
# **Input Features**
#
# **X1:** Transaction date (format: YYYY.MMDD, e.g., 2013.250 for March 2013, 2013.500 for June 2013)
#
# **X2:** House age (unit: years)
#
# **X3:** Distance to the nearest MRT station (unit: meters)
#
# **X4:** Number of convenience stores within walking distance (integer)
#
# **X5:** Geographic coordinate, latitude (unit: degrees)
#
# **X6:** Geographic coordinate, longitude (unit: degrees)
#
# **Target Feature**
#
# **Y:** House price per unit area (10,000 New Taiwan Dollars per Ping)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# **Missing Data**

# %%
data.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# Clearly we can say that there is no null values in dataset

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff  # Import the figure_factory module

def create_numerical_plots(data, feature):
    # Create subplots with 1 rows and 2 columns
    fig = make_subplots(rows=1, cols=2, subplot_titles=[f"Boxplot", f"Histogram"])

    # Add Boxplot for the specified feature
    fig.add_trace(go.Box(y=data[feature].values, name=feature),
                  row=1, col=1)

    # Create a Histogram for the specified feature
    fig.add_trace(go.Histogram(x=data[feature].values, nbinsx=10), row=1, col=2)

    # Update layout with title and remove legend
    fig.update_layout(title_text=f"Distribution Analysis for '{feature}' feature ",
                      showlegend=False)

    # Show the figure
    fig.show()

# %%
create_numerical_plots(data, "X2 house age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **House Age Boxplot**
#
# The boxplot reveals that house age in Sindian District exhibits a moderate range, with the minimum value at 0 years and the maximum value at 43.8 years.The median house age stands at 16.1 years, indicating that a significant portion of houses fall within the range of 12 to 20 years old.
#
# **House Age Frequency Distribution**
#
# The histogram further illustrates the frequency distribution of house age. The most common house age category is between 12.5 and 17.4 years, with 112 observations.

# %%
create_numerical_plots(data, "X3 distance to the nearest MRT station")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Distance to MRT Station Distribution**
#
# The boxplot reveals that the distance to the nearest MRT station exhibits a moderate range with a few outliers detected. The median distance stands at 492.23 meters, indicating that most estates are located within a reasonable distance to public transportation.
#
# **Frequency Distribution of Distance to MRT Station**
#
# The histogram further illustrates the distribution of distances to MRT stations. The most common distance category is between 0 and 1 kilometer, with 276 out of 414 observations. This implies that a significant portion of estates are located within this proximity to MRT stations, indicating the convenience and accessibility of public transportation for residents in these areas

# %%
create_numerical_plots(data, "X4 number of convenience stores")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Boxplot Analysis**
#
# The boxplot reveals that the number of convenience stores near estates exhibits a moderate range with no outliers detected. The median number of convenience stores is 4, indicating that a majority of estates have a moderate number of convenience stores in their vicinity.
#
# **Frequency Distribution of Convenience Stores**
#
# The histogram further illustrates the distribution of convenience stores near estates. The most common count category is 0 or 1, with 113 observations out of 414. This implies that a significant portion of estates have either no convenience stores or a very small number of convenience stores in their immediate surroundings.

# %%
sns.displot(data= data, x='Y house price of unit area' , bins=25 , kde=True)

# %%
data.hist(bins = 10 , figsize = (20,15))
plt.show()

# %%
sns.heatmap(data.corr(), annot=True, cmap='inferno')
# Out:
# <Axes: >

# %% [markdown]
# **Data Splitting and Testing**

# %%
#defining features and the label

X = data.drop('Y house price of unit area',axis=1)
y = data['Y house price of unit area']

# %%
#preprocessing

from sklearn.preprocessing import PolynomialFeatures

polynomial_converter=PolynomialFeatures(degree=2, include_bias=False)
poly_features=polynomial_converter.fit_transform(X)
poly_features.shape
# Out:
# (414, 35)

# %%
X.shape
# Out:
# (414, 7)

# %%
#spliting the dataset to work on train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)

# %%
#Training the model

from sklearn.linear_model import LinearRegression

poly_model=LinearRegression()
poly_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#predicting Test

y_pred=poly_model.predict(X_test)
pd.DataFrame({'Y_Test': y_test,'Y_Pred':y_pred, 'Residuals':(y_test-y_pred) }).head(8)
# Out:
#      Y_Test     Y_Pred  Residuals
# 176    19.2  16.382290   2.817710
# 347    11.2   3.929467   7.270533
# 307    24.7  17.438173   7.261827
# 299    46.1  47.146074  -1.046074
# 391    31.3  27.340929   3.959071
# 212    31.1  33.198376  -2.098376
# 104    30.5  35.522555  -5.022555
# 311    42.2  38.089539   4.110461

# %%
#Testing the model

from sklearn import metrics


MAE_Poly = metrics.mean_absolute_error(y_test,y_pred)
MSE_Poly = metrics.mean_squared_error(y_test,y_pred)
RMSE_Poly = np.sqrt(MSE_Poly)

pd.DataFrame([MAE_Poly, MSE_Poly, RMSE_Poly], index=['MAE', 'MSE', 'RMSE'], columns=['metrics'])
# Out:
#         metrics
# MAE    4.490908
# MSE   32.402925
# RMSE   5.692357

# %%
train_RMSE_list=[]
test_RMSE_list=[]

for d in range(1,10):


    polynomial_converter= PolynomialFeatures(degree=d, include_bias=False)
    poly_features= polynomial_converter.fit_transform(X)


    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)


    poly_model=LinearRegression()
    poly_model.fit(X_train, y_train)


    y_train_predict=poly_model.predict(X_train)
    y_test_predict=poly_model.predict(X_test)

    train_RMSE=np.sqrt(metrics.mean_squared_error(y_train, y_train_predict))


    test_RMSE=np.sqrt(metrics.mean_squared_error(y_test, y_test_predict))


    train_RMSE_list.append(train_RMSE)
    test_RMSE_list.append(test_RMSE)

# %%
train_RMSE_list
# Out:
# [9.537106820862302,
#  8.037433071311783,
#  7.100080276503018,
#  7.017017581626606,
#  1.8069457816781935,
#  0.5162745840125628,
#  0.7258656397545291,
#  0.37810260950930225,
#  0.43538261547958906]

# %%
test_RMSE_list
# Out:
# [6.773500382280134,
#  5.6923567585845065,
#  23.790939357612945,
#  270.16672201520834,
#  6269.455601724226,
#  33647.39515124204,
#  201565.15887126033,
#  1588562.8354782546,
#  15011414.555628521]

# %%
plt.plot(range(1,5), train_RMSE_list[:4],label='Train RMSE',color='b')
plt.plot(range(1,5), test_RMSE_list[:4],label='Test RMSE',color='r')

plt.xlabel('Polynomial Degree')
plt.ylabel('RMSE')
plt.legend()

# %% [markdown]
# # **Now we figured out that the number 2 is the best degree for our polynomial model**

# %%
polynomial_converter= PolynomialFeatures(degree=9)
poly_features= polynomial_converter.fit(X)
poly_features= polynomial_converter.transform(X)

# %%
# Fit polynomial regression
degree = 2
poly_features = PolynomialFeatures(degree=degree)
X_poly = poly_features.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Visualize the polynomial regression
X_new = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
X_new_poly = poly_features.transform(X)
y_new = model.predict(X_new_poly)

# %%
# Assuming you want to predict house prices based on a single feature, say 'X1'
X = data[['X2 house age']].values
y = data['Y house price of unit area'].values

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Assuming you want to predict house prices based on a single feature, say 'X1'
X = data[['X2 house age']].values
y = data['Y house price of unit area'].values

# Fit polynomial regression
degree = 2
poly_features = PolynomialFeatures(degree=degree)
X_poly = poly_features.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)

# Visualize the polynomial regression
X_new = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
X_new_poly = poly_features.transform(X_new)
y_new = model.predict(X_new_poly)

plt.scatter(X, y, label='Original data')
plt.plot(X_new, y_new, color='red', label='Polynomial regression')
plt.xlabel('X2 house age')
plt.ylabel('Y house price of unit area')
plt.title('Polynomial Regression')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Assuming you want to predict house prices based on a single feature, say 'X1'
X = data[['X4 number of convenience stores']].values
y = data['Y house price of unit area'].values

# Fit polynomial regression
degree = 2
poly_features = PolynomialFeatures(degree=degree)
X_poly = poly_features.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)

# Visualize the polynomial regression
X_new = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
X_new_poly = poly_features.transform(X_new)
y_new = model.predict(X_new_poly)

plt.scatter(X, y, label='Original data')
plt.plot(X_new, y_new, color='red', label='Polynomial regression')
plt.xlabel('X4 number of convenience stores')
plt.ylabel('Y house price of unit area')
plt.title('Polynomial Regression')
plt.legend()
plt.show()
